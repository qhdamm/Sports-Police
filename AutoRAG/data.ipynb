# %%
import pandas as pd

# %%
df = pd.read_parquet('./data/corpus.parquet')

# %%
df
# Out:
#                                   doc_id  \
# 0   1626f35b-7ffc-4736-bd6e-2a2f20e1aa8b
# 1   7be488a0-db14-4e95-938b-fefbb056d23a
# 2   b9c3d0ff-9d45-4022-83c3-07255441f63a
# 3   9b4ca509-a759-48ab-b63f-5af46134fc0d
# 4   a4c94f02-363e-4ef3-ac77-4b2700c00054
# ..                                   ...
# 58  9b7af456-2f27-4ed5-8ec7-0bc40d02cb78
# 59  4f93f302-2a53-4de4-9908-6b3fc09495e9
# 60  ed971817-63c2-4903-94a2-b09541cf0ced
# 61  d911e3f3-98dd-48a4-ace3-794a0f948c70
# 62  20be33f3-9c87-47af-b77c-c456c3e218f6
#
#                                              contents  \
# 0   ## K**Eywords** Large Language Models · Pre-Tr...
# 1   # Large Language Model-Based Interpretable Mac...
# 2   # How Secure Are Large Language Models (Llms) ...
# 3   # Inadequacies Of Large Language Model Benchma...
# 4   # Rag-Driver: Generalisable Driving Explanatio...
# ..                                                ...
# 58  # Jailbreaking Proprietary Large Language Mode...
# ...

# %%
df1 = pd.read_parquet('/root/corpus_1.parquet')

# %%
df1
# Out:
#                                     doc_id  \
# 0     302fcea3-07f4-4795-84f4-d225f7596b90
# 1     7f6bc07d-6a95-4441-bbdd-99757dcb6478
# 2     2816df21-0a07-4dc9-8ff6-a2da94d419fc
# 3     45fd0228-b655-4825-a135-82a4e9fc207f
# 4     53694772-269b-45d5-80f2-284febc46210
# ...                                    ...
# 2446  57acfda3-e32e-47fe-92ea-392eace96fac
# 2447  f8c8aa71-9db7-45f5-be54-d710b6e0b2d4
# 2448  720edc4c-4d78-47f4-88ee-36ce88efc94c
# 2449  b1f97885-50c1-4dc0-9bc6-d034bba82997
# 2450  2bd42317-9592-4f59-91c2-fc8a70cf1cea
#
#                                                contents  \
# 0     COMPETITION\n\nREGULATIONS\n\nIn force as from...
# 1     1 GENERAL RULES FOR OLYMPIC GAMES, WORLD CHAMP...
# 2     3 SPORT NATIONALITY .............................
# 3     5 ELIGIBILITY REQUIREMENTS FOR COMPETITION AND...
# 4     7 SWIMWEAR AND WEARABLES ........................
# ...                                                 ...
# ...
